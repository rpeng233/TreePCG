# %% [markdown]
# ### A plot of julia 64,1024 vs python 64,1024 vs matlab 64,1024 for rand_1000_u1000

# %%
include("../src/Julia.jl")
# Out:
# parseMatlabData (generic function with 1 method)

# %%
jul64 = parseData("../../graphs/rand_1000_u1000/_log_julia_tree1_64.txt")
pyt64 = parsePythonData("../../graphs/rand_1000_u1000/_log_python_tree_1_39_100iters.csv")
mat64 = parseMatlabData("../../graphs/rand_1000_u1000/_log_matlab_tree1_64precision_100iters.txt")

jul1024= parseData("../../graphs/rand_1000_u1000/_log_julia_tree1_1024.txt")
pyt1024 = parsePythonData("../../graphs/rand_1000_u1000/_log_python_tree_1_309_100iters.csv")
mat1024 = parseMatlabData("../../graphs/rand_1000_u1000/_log_matlab_tree1_1024precision_100iters.txt");

# %%
#2 norm plot
dataj2 = [Array{Float64,1}(0) for i in 1:2]
datap2 = [Array{Float64,1}(0) for i in 1:2]
datam2 = [Array{Float64,1}(0) for i in 1:2]

println(length(pyt64))

for i in 1:100
    push!(dataj2[1], jul64[i][2])
    push!(dataj2[2], jul1024[i][2])
    
    push!(datap2[1], pyt64[i][2])
    push!(datap2[2], pyt1024[i][2])
    
    push!(datam2[1], mat64[i][2])
    push!(datam2[2], mat1024[i][2])
end
# Out:
# 100

# %%
plot(log(dataj2[1]), label="julia default", linewidth=2)
plot(log(dataj2[2]), label="julia 1024", linewidth=2)

plot(log(datap2[1]), label="python default", linewidth=2)
plot(log(datap2[2])-0.1, label="python 1024", linewidth=2)

plot(log(datam2[1]), label="matlab default", linewidth=2)
plot(log(datam2[2])-0.2, label="matlab 1024", linewidth=2)

legend(fontsize=7)
ylabel("Relative 2-norm")
xlabel("PCG Iterations")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31fa42210>)
# PyObject <matplotlib.text.Text object at 0x320763a90>

# %%
#A norm plot
datajA = [Array{Float64,1}(0) for i in 1:2]
datapA = [Array{Float64,1}(0) for i in 1:2]
datamA = [Array{Float64,1}(0) for i in 1:2]

for i in 1:100
    push!(datajA[1], jul64[i][1])
    push!(datajA[2], jul1024[i][1])
    
    push!(datapA[1], pyt64[i][1])
    push!(datapA[2], pyt1024[i][1])
    
    push!(datamA[1], mat64[i][1])
    push!(datamA[2], mat1024[i][1])
end

# %%
plot(log(datajA[1]), label="julia default", linewidth=2)
plot(log(datajA[2]), label="julia 1024", linewidth=2)

plot(log(datapA[1]), label="python default", linewidth=2)
plot(log(datapA[2])-0.1, label="python 1024", linewidth=2)

plot(log(datamA[1]), label="matlab default", linewidth=2)
plot(log(datamA[2])-0.2, label="matlab 1024", linewidth=2)

legend(fontsize=7)
ylabel("Relative A-norm")
xlabel("PCG Iterations")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x32023b490>)
# PyObject <matplotlib.text.Text object at 0x320245e50>
