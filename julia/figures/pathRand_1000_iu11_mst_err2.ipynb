# %% [markdown]
# ### the graph should actually be called iu11

# %%
include("../src/Julia.jl")
# Out:
# parseCPPData (generic function with 1 method)

# %%
prec = ["double", "mpfr_64", "mpfr_128", "mpfr_256", "mpfr_512", "mpfr_1024"];

# %%
cpp = []
for p in 1:6
    println("**** ", prec[p])
    push!(cpp, parseCPPData("../../graphs/pathRand_1000_u11_dup/_log_" * prec[p] * ".txt"))
end
# Out:
# **** double
# **** mpfr_64
# **** mpfr_128
# **** mpfr_256
# **** mpfr_512
# **** mpfr_1024

# %%
for p in 1:6
    plot(log(cpp[p][1:70]), label="C++ " * prec[p], linewidth=2)
end

# legend(fontsize=7)
ylabel("Relative 2-norm")
xlabel("PCG Iterations")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f73d6d0>)
# PyObject <matplotlib.text.Text object at 0x31faa2a50>
